# %% [markdown]
# # N-Grams: TBMM

# %% [markdown]
# Importing needed libraries.

# %%
import os
import re
from nltk.util import ngrams
from nltk.corpus import stopwords 
# import plotly.express as px

# %% [markdown]
# Defining the functions to be used.

# %%
def load_donem_data(donem_number):
    
    """Returns all the text found in a donem directory"""
    
    donem_text = ''
    donem_dir_path = os.path.join(os.getcwd(), f'NLP/donem{donem_number}') 
    walks = os.walk(donem_dir_path)
    for walk in walks:
        path, dirs, files = walk
        for file in files:
            file_path = os.path.join(path, file)
            if not file_path.endswith('txt'): continue  # avoid reading .DS_Store files (for mac users)
            with open(file_path, 'r') as f:
                donem_text += f.read()
    return donem_text 


def extract_n_grams(donem_number, n_grams):
    
    """Returns n_grams generator given a donem_number and the 'n' value"""
    
    donem_text = load_donem_data(donem_number)
    n_grams = ngrams(donem_text.split(), n_grams)
    return n_grams 

def process_n_grams():
    """This function will process the N-grams after they are extracted.
        For example, removing the unigrams that consist of only a single letter. 
    
    """
    pass

# %% [markdown]
# ### Donem<span style="color:red;"> 20<span>

# %%
unigrams = extract_n_grams(20, 1)
bigrams = extract_n_grams(20, 2)
trigrams = extract_n_grams(20, 3)

# %%
bigrams_list = list(bigrams)

# %%
bigrams_list
# Out:
# [('DÖNEM', ':'),
#  (':', '20'),
#  ('20', 'CİLT'),
#  ('CİLT', ':'),
#  (':', '3'),
#  ('3', 'YASAMA'),
#  ('YASAMA', 'YILI'),
#  ('YILI', ':'),
#  (':', '1'),
#  ('1', 'T.'),
#  ('T.', 'B.'),
#  ('B.', 'M.'),
#  ('M.', 'M.'),
#  ('M.', 'TUTANAK'),
#  ('TUTANAK', 'DERGİSİ'),
#  ('DERGİSİ', '38'),
#  ('38', 'inci'),
#  ('inci', 'Birleşim'),
#  ('Birleşim', '17'),
#  ('17', '.'),
#  ('.', '4'),
#  ('4', '.'),
#  ('.', '1996'),
#  ('1996', 'Çarşamba'),
#  ('Çarşamba', 'İ'),
#  ('İ', 'Ç'),
#  ('Ç', 'İ'),
#  ('İ', 'N'),
#  ('N', 'D'),
#  ('D', 'E'),
#  ('E', 'K'),
#  ('K', 'İ'),
#  ('İ', 'L'),
#  ('L', 'E'),
#  ('E', 'R'),
#  ('R', 'I.'),
#  ('I.', '–'),
#  ('–', 'GEÇEN'),
#  ('GEÇEN', 'TUTANAK'),
#  ('TUTANAK', 'ÖZETİ'),
#  ('ÖZETİ', 'II.'),
#  ('II.', '–'),
#  ('–', 'KANUN'),
#  ('KANUN', 'TASARI'),
#  ('TASARI', 'VE'),
#  ('VE', 'TEKLİFLERİYLE'),
#  ('TEKLİFLERİYLE', 'KOMİSYONLARDAN'),
#  ('KOMİSYONLARDAN', 'GELEN'),
#  ('GELEN', 'DİĞER'),
#  ('DİĞER', 'İŞLER'),
#  ('İŞLER', '1.'),
#  ('1.', '–'),
#  ('–', '1996'),
#  ('1996', 'Malî'),
#  ('Malî', 'Yılı'),
#  ('Yılı', 'Bütçe'),
#  ('Bütçe', 'Kanunu'),
#  ('Kanunu', 'Tasarısı'),
#  ('Tasarısı', 've'),
#  ('ve', 'Plan'),
#  ('Plan', 've'),
#  ('ve', 'Bütçe'),
#  ('Bütçe', 'Komisyonu'),
#  ('Komisyonu', 'Raporu'),
#  ('Raporu', '(1/285)'),
#  ('(1/285)', '(S.'),
#  ('(S.', 'Sayısı'),
#  ('Sayısı', ':'),
#  (':', '1)'),
#  ('1)', '2.'),
#  ('2.', '–'),
#  ('–', 'Katma'),
#  ('Katma', 'Bütçeli'),
#  ('Bütçeli', 'İdareler'),
#  ('İdareler', '1996'),
#  ('1996', 'Malî'),
#  ('Malî', 'Yılı'),
#  ('Yılı', 'Bütçe'),
#  ('Bütçe', 'Kanunu'),
#  ('Kanunu', 'Tasarısı'),
#  ('Tasarısı', 've'),
#  ('ve', 'Plan'),
#  ('Plan', 've'),
#  ('ve', 'Bütçe'),
#  ('Bütçe', 'Komisyonu'),
#  ('Komisyonu', 'Raporu'),
#  ('Raporu', '(1/286)(S.'),
#  ('(1/286)(S.', 'Sayısı'),
#  ('Sayısı', ':'),
#  (':', '2)'),
#  ('2)', 'III.'),
#  ('III.', '–'),
#  ('–', 'SATAŞMALARA'),
#  ('SATAŞMALARA', 'İLİŞKİN'),
#  ('İLİŞKİN', 'KONUŞMALAR'),
#  ('KONUŞMALAR', '1.'),
#  ('1.', '–'),
#  ('–', 'Antalya'),
#  ('Antalya', 'Milletvekili'),
#  ('Milletvekili', 'Deniz'),
#  ('Deniz', 'Baykal’ın,'),
#  ('Baykal’ın,', 'Başbakan'),
#  ('Başbakan', 'Mesut'),
#  ('Mesut', 'Yılmaz’ın'),
#  ('Yılmaz’ın', 'şahsına'),
#  ('şahsına', 'sataşması'),
#  ('sataşması', 'nedeniyle'),
#  ('nedeniyle', 'konuşması'),
#  ('konuşması', 'IV.'),
#  ('IV.', '–'),
#  ('–', 'SORULAR'),
#  ('SORULAR', 'VE'),
#  ('VE', 'CEVAPLAR'),
#  ('CEVAPLAR', 'A)'),
#  ('A)', 'YAZILI'),
#  ('YAZILI', 'SORULAR'),
#  ('SORULAR', 'VE'),
#  ('VE', 'CEVAPLARI'),
#  ('CEVAPLARI', '1.'),
#  ('1.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Bülent'),
#  ('Bülent', 'Akarcalı’nın,'),
#  ('Akarcalı’nın,', 'üniversiteye'),
#  ('üniversiteye', 'giriş'),
#  ('giriş', 'sınavı'),
#  ('sınavı', 'başvurusunda'),
#  ('başvurusunda', 'izdihama'),
#  ('izdihama', 'neden'),
#  ('neden', 'olan'),
#  ('olan', 'idareciler'),
#  ('idareciler', 'hakkında'),
#  ('hakkında', 'soruşturma'),
#  ('soruşturma', 'açılıp'),
#  ('açılıp', 'açılmayacağına'),
#  ('açılmayacağına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Millî'),
#  ('Millî', 'Eğitim'),
#  ('Eğitim', 'Bakanı'),
#  ('Bakanı', 'Turhan'),
#  ('Turhan', 'Tayan’ın'),
#  ('Tayan’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/13)'),
#  ('(7/13)', '2.'),
#  ('2.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', '1994-1995'),
#  ('1994-1995', 'yıllarında'),
#  ('yıllarında', 'maden'),
#  ('maden', 'fonundan'),
#  ('fonundan', 'verilen'),
#  ('verilen', 'kredilere'),
#  ('kredilere', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Enerji'),
#  ('Enerji', 've'),
#  ('ve', 'Tabiî'),
#  ('Tabiî', 'Kaynaklar'),
#  ('Kaynaklar', 'Bakanı'),
#  ('Bakanı', 'Hüsnü'),
#  ('Hüsnü', 'Doğan’ın'),
#  ('Doğan’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/196)'),
#  ('(7/196)', '3.'),
#  ('3.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', 'Özelleştirme'),
#  ('Özelleştirme', 'İdaresi'),
#  ('İdaresi', 'Başkanlığının'),
#  ('Başkanlığının', '1995'),
#  ('1995', 'yılı'),
#  ('yılı', 'reklam'),
#  ('reklam', 'harcamalarına'),
#  ('harcamalarına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Rüşdü'),
#  ('Rüşdü', 'Saracoglu’nun'),
#  ('Saracoglu’nun', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/249)'),
#  ('(7/249)', '4.'),
#  ('4.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', 'Çay'),
#  ('Çay', 'İşletmeleri'),
#  ('İşletmeleri', 'Genel'),
#  ('Genel', 'Müdürlüğünün'),
#  ('Müdürlüğünün', '1995'),
#  ('1995', 'yılı'),
#  ('yılı', 'reklam'),
#  ('reklam', 'harcamalarına'),
#  ('harcamalarına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Eyüp'),
#  ('Eyüp', 'Aşık’ın'),
#  ('Aşık’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/252)'),
#  ('(7/252)', '5.'),
#  ('5.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', 'Tekel'),
#  ('Tekel', 'Genel'),
#  ('Genel', 'Müdürlüğünün'),
#  ('Müdürlüğünün', '1995'),
#  ('1995', 'yılı'),
#  ('yılı', 'reklam'),
#  ('reklam', 'harcamalarına'),
#  ('harcamalarına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Eyüp'),
#  ('Eyüp', 'Aşık’ın'),
#  ('Aşık’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/254)'),
#  ('(7/254)', '6.'),
#  ('6.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', 'Yalova-Termal’deki'),
#  ('Yalova-Termal’deki', 'Türk'),
#  ('Türk', 'Hamamının'),
#  ('Hamamının', 'bakım'),
#  ('bakım', 'ihalesine'),
#  ('ihalesine', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Agâh'),
#  ('Agâh', 'Oktay'),
#  ('Oktay', 'Güner’in'),
#  ('Güner’in', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/288)'),
#  ('(7/288)', '7.'),
#  ('7.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Algan'),
#  ('Algan', 'Hacaloğlu’nun,'),
#  ('Hacaloğlu’nun,', 'çay'),
#  ('çay', 'ithalinde'),
#  ('ithalinde', 'uygulanan'),
#  ('uygulanan', 'rejime'),
#  ('rejime', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Eyüp'),
#  ('Eyüp', 'Aşık’ın'),
#  ('Aşık’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/290)'),
#  ('(7/290)', '8.'),
#  ('8.', '–'),
#  ('–', 'Rize'),
#  ('Rize', 'Milletvekili'),
#  ('Milletvekili', 'Ahmet'),
#  ('Ahmet', 'Kabil’in,'),
#  ('Kabil’in,', 'ÇAY-KUR'),
#  ('ÇAY-KUR', 'Genel'),
#  ('Genel', 'Müdürlüğünün'),
#  ('Müdürlüğünün', 'borçlarına'),
#  ('borçlarına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Eyüp'),
#  ('Eyüp', 'Aşık’ın'),
#  ('Aşık’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/300)'),
#  ('(7/300)', '9.'),
#  ('9.', '–'),
#  ('–', 'Kocaeli'),
#  ('Kocaeli', 'Milletvekili'),
#  ('Milletvekili', 'Bekir'),
#  ('Bekir', 'Yurdagül’ün,'),
#  ('Yurdagül’ün,', 'özelleştirme'),
#  ('özelleştirme', 'uygulamalarına'),
#  ('uygulamalarına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Rüşdü'),
#  ('Rüşdü', 'Saracoglu’nun'),
#  ('Saracoglu’nun', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/312)'),
#  ('(7/312)', '10.'),
#  ('10.', '–'),
#  ('–', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'Halit'),
#  ('Halit', 'Dumankaya’nın,'),
#  ('Dumankaya’nın,', 'özelleştirme'),
#  ('özelleştirme', 'için'),
#  ('için', 'ödenen'),
#  ('ödenen', 'danışmanlık'),
#  ('danışmanlık', 've'),
#  ('ve', 'reklam'),
#  ('reklam', 'ücretlerine'),
#  ('ücretlerine', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Rüşdü'),
#  ('Rüşdü', 'Saracoglu’nun'),
#  ('Saracoglu’nun', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/327)'),
#  ('(7/327)', '11.'),
#  ('11.', '–'),
#  ('–', 'Muğla'),
#  ('Muğla', 'Milletvekili'),
#  ('Milletvekili', 'Zeki'),
#  ('Zeki', 'Çakıroğlu’nun,'),
#  ('Çakıroğlu’nun,', 'Muğla'),
#  ('Muğla', 'TEK'),
#  ('TEK', 'Müdürlüğünce'),
#  ('Müdürlüğünce', 'kaçak'),
#  ('kaçak', 'bir'),
#  ('bir', 'inşaata'),
#  ('inşaata', 'elektrik'),
#  ('elektrik', 'bağlandığı'),
#  ('bağlandığı', 'iddiasına'),
#  ('iddiasına', 'ilişkin'),
#  ('ilişkin', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Enerji'),
#  ('Enerji', 've'),
#  ('ve', 'Tabiî'),
#  ('Tabiî', 'Kaynaklar'),
#  ('Kaynaklar', 'Bakanı'),
#  ('Bakanı', 'Hüsnü'),
#  ('Hüsnü', 'Doğan’ın'),
#  ('Doğan’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/330)'),
#  ('(7/330)', '12.'),
#  ('12.', '–'),
#  ('–', 'Konya'),
#  ('Konya', 'Milletvekili'),
#  ('Milletvekili', 'Hüseyin'),
#  ('Hüseyin', 'Arı’nın,'),
#  ('Arı’nın,', 'Konya-Adana'),
#  ('Konya-Adana', 'yolu'),
#  ('yolu', 'üzerinde'),
#  ('üzerinde', 'bulunan'),
#  ('bulunan', 'bazı'),
#  ('bazı', 'yerleşim'),
#  ('yerleşim', 'birimlerinin'),
#  ('birimlerinin', 'yol'),
#  ('yol', 'düzenlemesine'),
#  ('düzenlemesine', 'ilişkin'),
#  ('ilişkin', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Bayındırlık'),
#  ('Bayındırlık', 've'),
#  ('ve', 'İskân'),
#  ('İskân', 'Bakanı'),
#  ('Bakanı', 'Mehmet'),
#  ('Mehmet', 'Keçeciler’in'),
#  ('Keçeciler’in', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/335)'),
#  ('(7/335)', '13.'),
#  ('13.', '–'),
#  ('–', 'Rize'),
#  ('Rize', 'Milletvekili'),
#  ('Milletvekili', 'Şevki'),
#  ('Şevki', 'Yılmaz’ın,'),
#  ('Yılmaz’ın,', 'yaş'),
#  ('yaş', 'çay'),
#  ('çay', 'bedellerine'),
#  ('bedellerine', 'ilişkin'),
#  ('ilişkin', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Eyüp'),
#  ('Eyüp', 'Aşık’ın'),
#  ('Aşık’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/411)'),
#  ('(7/411)', '14.'),
#  ('14.', '–'),
#  ('–', 'Kocaeli'),
#  ('Kocaeli', 'Milletvekili'),
#  ('Milletvekili', 'Bekir'),
#  ('Bekir', 'Yurdagül’ün'),
#  ('Yurdagül’ün', 'amme'),
#  ('amme', 'alacaklarına'),
#  ('alacaklarına', 'uygulanacak'),
#  ('uygulanacak', 'gecikme'),
#  ('gecikme', 'zammı'),
#  ('zammı', 'ile'),
#  ('ile', 'ilgili'),
#  ('ilgili', 'Bakanlar'),
#  ('Bakanlar', 'Kurulu'),
#  ('Kurulu', 'Kararına'),
#  ('Kararına', 'ilişkin'),
#  ('ilişkin', 'Başbakandan'),
#  ('Başbakandan', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Maliye'),
#  ('Maliye', 'Bakanı'),
#  ('Bakanı', 'Lutfullah'),
#  ('Lutfullah', 'Kayalar’ın'),
#  ('Kayalar’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/437)'),
#  ('(7/437)', '15.'),
#  ('15.', '–'),
#  ('–', 'Kırıkkale'),
#  ('Kırıkkale', 'Milletvekili'),
#  ('Milletvekili', 'Kemal'),
#  ('Kemal', 'Albayrak’ın,'),
#  ('Albayrak’ın,', 'Tarım'),
#  ('Tarım', 'Kredi'),
#  ('Kredi', 'Kooperatifi'),
#  ('Kooperatifi', 'Yönetim'),
#  ('Yönetim', 'Kurulu'),
#  ('Kurulu', 'üyeliklerine'),
#  ('üyeliklerine', 'yapılan'),
#  ('yapılan', 'atamalara'),
#  ('atamalara', 've'),
#  ('ve', 'gübre'),
#  ('gübre', 'fiyatlarına'),
#  ('fiyatlarına', 'ilişkin'),
#  ('ilişkin', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Tarım'),
#  ('Tarım', 've'),
#  ('ve', 'Köyişleri'),
#  ('Köyişleri', 'Bakanı'),
#  ('Bakanı', 'İsmet'),
#  ('İsmet', 'Attila’nın'),
#  ('Attila’nın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/449)'),
#  ('(7/449)', '16.'),
#  ('16.', '–'),
#  ('–', 'Diyarbakır'),
#  ('Diyarbakır', 'Milletvekili'),
#  ('Milletvekili', 'Sacit'),
#  ('Sacit', 'Günbey’in,'),
#  ('Günbey’in,', 'Diyarbakır’daki'),
#  ('Diyarbakır’daki', 'elektrik'),
#  ('elektrik', 'kesintilerine'),
#  ('kesintilerine', 'ilişkin'),
#  ('ilişkin', 'sorusu'),
#  ('sorusu', 've'),
#  ('ve', 'Enerji'),
#  ('Enerji', 've'),
#  ('ve', 'Tabiî'),
#  ('Tabiî', 'Kaynaklar'),
#  ('Kaynaklar', 'Bakanı'),
#  ('Bakanı', 'Hüsnü'),
#  ('Hüsnü', 'Doğan’ın'),
#  ('Doğan’ın', 'yazılı'),
#  ('yazılı', 'cevabı'),
#  ('cevabı', '(7/467)'),
#  ('(7/467)', 'I.'),
#  ('I.', '–'),
#  ('–', 'GEÇEN'),
#  ('GEÇEN', 'TUTANAK'),
#  ('TUTANAK', 'ÖZETİ'),
#  ('ÖZETİ', 'TBMM'),
#  ('TBMM', 'Genel'),
#  ('Genel', 'Kurulu'),
#  ('Kurulu', 'saat'),
#  ('saat', '15.00’te'),
#  ('15.00’te', 'toplanarak'),
#  ('toplanarak', 'iki'),
#  ('iki', 'oturum'),
#  ('oturum', 'yaptı.'),
#  ('yaptı.', 'Turizm'),
#  ('Turizm', 'Bakanı'),
#  ('Bakanı', 'Işılay'),
#  ('Işılay', 'Saygın,'),
#  ('Saygın,', 'Turizm'),
#  ('Turizm', 'Haftası'),
#  ('Haftası', 'nedeniyle,'),
#  ('nedeniyle,', 'turizm'),
#  ('turizm', 'sektöründeki'),
#  ('sektöründeki', 'son'),
#  ('son', 'gelişmeler'),
#  ('gelişmeler', 've'),
#  ('ve', 'Turizm'),
#  ('Turizm', 'Bakanlığının'),
#  ('Bakanlığının', 'faaliyetleri'),
#  ('faaliyetleri', 'konusunda'),
#  ('konusunda', 'gündemdışı'),
#  ('gündemdışı', 'açıklamada'),
#  ('açıklamada', 'bulundu;'),
#  ('bulundu;', 'DSP'),
#  ('DSP', 'Grubu'),
#  ('Grubu', 'adına'),
#  ('adına', 'İzmir'),
#  ('İzmir', 'Milletvekili'),
#  ('Milletvekili', 'Atilla'),
#  ('Atilla', 'Mutman,'),
#  ('Mutman,', 'CHP'),
#  ('CHP', 'Grubu'),
#  ('Grubu', 'adına'),
#  ('adına', 'Kırklareli'),
#  ('Kırklareli', 'Milletvekili'),
#  ('Milletvekili', 'İrfan'),
#  ('İrfan', 'Gürpınar,'),
#  ('Gürpınar,', 'DYP'),
#  ('DYP', 'Grubu'),
#  ('Grubu', 'adına'),
#  ('adına', 'Balıkesir'),
#  ('Balıkesir', 'Milletvekili'),
#  ('Milletvekili', 'İlyas'),
#  ('İlyas', 'Yılmazyıldız,'),
#  ('Yılmazyıldız,', 'RP'),
#  ('RP', 'Grubu'),
#  ('Grubu', 'adına'),
#  ('adına', 'Ankara'),
#  ('Ankara', 'Milletvekili'),
#  ('Milletvekili', 'Hasan'),
#  ('Hasan', 'Hüseyin'),
#  ('Hüseyin', 'Ceylan,'),
#  ('Ceylan,', 'ANAP'),
#  ('ANAP', 'Grubu'),
#  ('Grubu', 'adına'),
#  ('adına', 'Nevşehir'),
#  ('Nevşehir', 'Milletvekili'),
#  ('Milletvekili', 'Abdülkadir'),
#  ('Abdülkadir', 'Baş'),
#  ('Baş', 'da'),
#  ('da', 'aynı'),
#  ('aynı', 'konuda'),
#  ('konuda', 'görüşlerini'),
#  ('görüşlerini', 'açıkladılar.'),
#  ('açıkladılar.', 'Edirne'),
#  ('Edirne', 'Milletvekili'),
#  ('Milletvekili', 'Erdal'),
#  ('Erdal', 'Kesebir’in,'),
#  ('Kesebir’in,', 'medyada'),
#  ('medyada', 've'),
#  ('ve', 'yazılı'),
#  ('yazılı', 'basında'),
#  ('basında', 'devletin'),
#  ('devletin', 'varlığı'),
#  ('varlığı', 've'),
#  ('ve', 'otoritesinin'),
#  ('otoritesinin', 'tartışılmasına'),
#  ('tartışılmasına', 'neden'),
#  ('neden', 'olabilecek'),
#  ('olabilecek', 'bazı'),
#  ('bazı', 'yayınlar'),
#  ('yayınlar', 'yapıldığı'),
#  ('yapıldığı', 'iddialarına'),
#  ('iddialarına', 'ilişkin'),
#  ('ilişkin', 'gündemdışı'),
#  ('gündemdışı', 'konuşmasına,'),
#  ('konuşmasına,', 'Adalet'),
#  ('Adalet', 'Bakanı'),
#  ('Bakanı', 'Mehmet'),
#  ('Mehmet', 'Ağar;'),
#  ('Ağar;', 'Kars'),
#  ('Kars', 'Milletvekili'),
#  ('Milletvekili', 'Çetin'),
#  ('Çetin', 'Bilgir’in,'),
#  ('Bilgir’in,', 'Doğu'),
#  ('Doğu', 'Anadolu'),
#  ('Anadolu', 'Bölgesinin'),
#  ('Bölgesinin', 'sorunlarına'),
#  ('sorunlarına', 've'),
#  ('ve', 'bölgede'),
#  ('bölgede', 'yaşanan'),
#  ('yaşanan', 'göç'),
#  ('göç', 'olayının'),
#  ('olayının', 'nedenlerine'),
#  ('nedenlerine', 'ilişkin'),
#  ('ilişkin', 'gündemdışı'),
#  ('gündemdışı', 'konuşmasına,'),
#  ('konuşmasına,', 'İçişleri'),
#  ('İçişleri', 'Bakanı'),
#  ('Bakanı', 'Ülkü'),
#  ('Ülkü', 'Güney;'),
#  ('Güney;', 'Cevap'),
#  ('Cevap', 'verdiler.'),
#  ('verdiler.', 'Kahramanmaraş'),
#  ('Kahramanmaraş', 'Milletvekili'),
#  ('Milletvekili', 'Mustafa'),
#  ('Mustafa', 'Kamalak,'),
#  ('Kamalak,', 'Güvenoylaması,'),
#  ('Güvenoylaması,', 'Çekiç'),
#  ('Çekiç', 'Güç'),
#  ('Güç', 've'),
#  ('ve', 'Olağanüstü'),
#  ('Olağanüstü', 'Hal'),
#  ('Hal', 'konularında'),
#  ('konularında', 'TBMM'),
#  ('TBMM', 'Genel'),
#  ('Genel', 'Kurulunda'),
#  ('Kurulunda', 'yapılan'),
#  ('yapılan', 'oylamaların'),
#  ('oylamaların', 'Anayasa'),
#  ('Anayasa', 've'),
#  ('ve', 'İçtüzük'),
#  ('İçtüzük', 'hükümlerine'),
#  ('hükümlerine', 'uygun'),
#  ('uygun', 'olarak'),
#  ('olarak', 'yerine'),
#  ('yerine', 'getirilmediği'),
#  ('getirilmediği', 've'),
#  ('ve', 'yapılan'),
#  ('yapılan', 'işlemlerin'),
#  ('işlemlerin', 'geçersiz'),
#  ('geçersiz', 'olduğu'),
#  ('olduğu', 'iddialarına'),
#  ('iddialarına', 'ilişkin'),
#  ('ilişkin', 'gündemdışı'),
#  ('gündemdışı', 'bir'),
#  ('bir', 'konuşma'),
#  ('konuşma', 'yaptı.'),
#  ('yaptı.', 'Başkanlıkça,'),
#  ('Başkanlıkça,', 'Genel'),
#  ('Genel', 'Kurulda'),
#  ('Kurulda', 'yapılan'),
#  ('yapılan', 'söz'),
#  ('söz', 'konusu'),
#  ('konusu', 'oylamaların'),
#  ('oylamaların', 'Anayasa'),
#  ('Anayasa', 've'),
#  ('ve', 'İçtüzük'),
#  ('İçtüzük', 'hükümlerine'),
#  ('hükümlerine', 'uygun'),
#  ('uygun', 'olarak'),
#  ('olarak', 'gerçekleştirildiğine'),
#  ('gerçekleştirildiğine', 'ilişkin'),
#  ('ilişkin', 'açıklamada'),
#  ('açıklamada', 'bulunuldu.'),
#  ('bulunuldu.', '53'),
#  ('53', 'üncü'),
#  ('üncü', 'Hükümetin'),
#  ('Hükümetin', 'güvenoyu'),
#  ('güvenoyu', 'almadığı,'),
#  ('almadığı,', 'Olağanüstü'),
#  ('Olağanüstü', 'Hal'),
#  ('Hal', 've'),
#  ('ve', 'Çekiç'),
#  ('Çekiç', 'Güç’ün'),
#  ('Güç’ün', 'Türkiye’de'),
#  ('Türkiye’de', 'kalma'),
#  ('kalma', 'süresinin'),
#  ('süresinin', 'Anayasa'),
#  ('Anayasa', 've'),
#  ('ve', 'İçtüzük'),
#  ('İçtüzük', 'hükümlerine'),
#  ('hükümlerine', 'uygun'),
#  ('uygun', 'olarak'),
#  ('olarak', 'uzatılmadığı'),
#  ('uzatılmadığı', 'iddialarıyla'),
#  ('iddialarıyla', 'ilgili'),
#  ('ilgili', 'TBMM'),
#  ('TBMM', 'Başkanlık'),
#  ('Başkanlık', 'Divanının'),
#  ('Divanının', 'toplanarak,'),
#  ('toplanarak,', 'takip'),
#  ('takip', 'edilecek'),
#  ('edilecek', 'yolun'),
#  ('yolun', 'kararlaştırılmasını'),
#  ('kararlaştırılmasını', 'talep'),
#  ('talep', 'eden'),
#  ('eden', 'RP'),
#  ('RP', 'Grubu'),
#  ('Grubu', 'Başkanlığının'),
#  ('Başkanlığının', 'ilgi'),
#  ('ilgi', 'yazısı'),
#  ('yazısı', 'üzerine,'),
#  ('üzerine,', 'söz'),
#  ('söz', 'konusu'),
#  ('konusu', 'oylamaların'),
#  ('oylamaların', 'Anayasa'),
#  ('Anayasa', 've'),
#  ('ve', 'İçtüzük'),
#  ('İçtüzük', 'hükümleri'),
#  ('hükümleri', 'çerçevesinde'),
#  ('çerçevesinde', 'gerçekleştirildiğine,'),
#  ('gerçekleştirildiğine,', 'yapılan'),
#  ('yapılan', 'işlemlerin'),
#  ('işlemlerin', 'hukuka'),
#  ('hukuka', 've'),
#  ('ve', 'teamüle'),
#  ('teamüle', 'uygun'),
#  ('uygun', 'olduğuna,'),
#  ('olduğuna,', 'bu'),
#  ('bu', 'nedenle'),
#  ('nedenle', 'Başkanlık'),
#  ('Başkanlık', 'Divanının'),
#  ('Divanının', 'konuyla'),
#  ('konuyla', 'ilgili'),
#  ('ilgili', 'olarak'),
#  ('olarak', 'toplantıya'),
#  ('toplantıya', 'çağrılmasına'),
#  ('çağrılmasına', 've'),
#  ('ve', 'başkaca'),
#  ('başkaca', 'işlem'),
#  ('işlem', 'yapılmasına'),
#  ('yapılmasına', 'gerek'),
#  ('gerek', 'görülmediğine'),
#  ('görülmediğine', 'ilişkin'),
#  ('ilişkin', 'TBMM'),
#  ('TBMM', 'Başkanlığı'),
#  ('Başkanlığı', 'yazısı'),
#  ('yazısı', 'okundu.'),
#  ('okundu.', 'Azerbaycan'),
#  ('Azerbaycan', 'Cumhuriyeti’ne'),
#  ('Cumhuriyeti’ne', 'gidecek'),
#  ('gidecek', 'olan'),
#  ('olan', ':'),
#  (':', 'Başbakan'),
#  ('Başbakan', 'A.'),
#  ('A.', 'Mesut'),
#  ('Mesut', 'Yılmaz’a,'),
#  ('Yılmaz’a,', 'dönüşüne'),
#  ('dönüşüne', 'kadar,'),
#  ('kadar,', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 've'),
#  ('ve', 'Başbakan'),
#  ('Başbakan', 'Yardımcısı'),
#  ('Yardımcısı', 'Nahit'),
#  ('Nahit', 'Menteşe’nin,'),
#  ('Menteşe’nin,', 'Enerji'),
#  ('Enerji', 've'),
#  ('ve', 'Tabiî'),
#  ('Tabiî', 'Kaynaklar'),
#  ('Kaynaklar', 'Bakanı'),
#  ('Bakanı', 'Hüsnü'),
#  ('Hüsnü', 'Doğan’a,'),
#  ('Doğan’a,', 'dönüşüne'),
#  ('dönüşüne', 'kadar,'),
#  ('kadar,', 'Devlet'),
#  ('Devlet', 'Bakanı'),
#  ('Bakanı', 'Rüşdü'),
#  ('Rüşdü', 'Saracoglu’nun,'),
#  ('Saracoglu’nun,', 'Vekâlet'),
#  ('Vekâlet', 'etmelerinin'),
#  ('etmelerinin', 'uygun'),
#  ('uygun', 'görülmüş'),
#  ('görülmüş', 'olduğuna'),
#  ('olduğuna', 'ilişkin'),
#  ('ilişkin', 'Cumhurbaşkanlığı'),
#  ('Cumhurbaşkanlığı', 'tezkereleri'),
#  ('tezkereleri', 'ile;'),
#  ('ile;', 'Eskişehir'),
#  ('Eskişehir', 'Milletvekili'),
#  ('Milletvekili', 'Demir'),
#  ('Demir', 'Berberoğlu’nun,'),
#  ('Berberoğlu’nun,', 'Sait'),
#  ('Sait', 'Halim'),
#  ('Halim', 'Paşa'),
#  ('Paşa', 'Yalısında'),
#  ('Yalısında', 'Meydana'),
#  ('Meydana', 'Gelen'),
#  ('Gelen', 'Yangının'),
#  ('Yangının', 'Nedenlerini'),
#  ('Nedenlerini', 've'),
#  ('ve', 'Turban'),
#  ('Turban', 'Genel'),
#  ('Genel', 'Müdürlüğü'),
#  ('Müdürlüğü', 'ile'),
#  ('ile', 'İlgili'),
#  ('İlgili', 'Yolsuzluk'),
#  ('Yolsuzluk', 'İddialarını'),
#  ('İddialarını', 'Araştırmak'),
#  ('Araştırmak', 'Üzere'),
#  ('Üzere', 'Kurulan'),
#  ('Kurulan', '(10/2)'),
#  ('(10/2)', 'Esas'),
#  ('Esas', 'Numaralı'),
#  ('Numaralı', 'Meclis'),
#  ('Meclis', 'Araştırma'),
#  ('Araştırma', 'Komisyonu'),
#  ('Komisyonu', 'Üyeliğinden'),
#  ('Üyeliğinden', 'çekildiğine'),
#  ('çekildiğine', 'ilişkin'),
#  ('ilişkin', 'önergesi;'),
#  ('önergesi;', 'Genel'),
#  ('Genel', 'Kurulun'),
#  ('Kurulun', 'bilgisine'),
#  ('bilgisine', 'sunuldu.'),
#  ('sunuldu.', 'Kocaeli'),
#  ('Kocaeli', 'Milletvekili'),
#  ('Milletvekili', 'Şevket'),
#  ('Şevket', 'Kazan'),
#  ('Kazan', 've'),
#  ('ve', '56'),
#  ('56', 'arkadaşının,'),
#  ('arkadaşının,', 'Türk'),
#  ('Türk', 'Otomobil'),
#  ('Otomobil', 'Fabrikaları'),
#  ('Fabrikaları', 'A.Ş.'),
#  ('A.Ş.', '(TOFAŞ)'),
#  ('(TOFAŞ)', 'ile'),
#  ('ile', 'TOFAŞ'),
#  ('TOFAŞ', 'Oto'),
#  ('Oto', 'Ticaret'),
#  ('Ticaret', 'A.Ş.’deki'),
#  ('A.Ş.’deki', 'devlete'),
#  ('devlete', 'ait'),
#  ('ait', 'hissenin'),
#  ('hissenin', 'satış'),
#  ('satış', 'yolu'),
#  ('yolu', 'ile'),
#  ('ile', 'Özelleştirme'),
#  ('Özelleştirme', 'sırasında'),
#  ('sırasında', 'nüfuzunu'),
#  ('nüfuzunu', 'kullanmak'),
#  ('kullanmak', 've'),
#  ('ve', 'ihaleye'),
#  ('ihaleye', 'fesat'),
#  ('fesat', 'karıştırmak'),
#  ('karıştırmak', 'suretiyle'),
#  ('suretiyle', 'devleti'),
#  ('devleti', 'zarara'),
#  ('zarara', 'uğratarak'),
#  ('uğratarak', 'güvenini'),
#  ('güvenini', 'kötüye'),
#  ('kötüye', 'kullandığı'),
#  ('kullandığı', 've'),
#  ('ve', 'bu'),
#  ('bu', 'eyleminin'),
#  ('eyleminin', 'Türk'),
#  ('Türk', 'Ceza'),
#  ('Ceza', 'Kanununun'),
#  ('Kanununun', '240'),
#  ('240', 've'),
#  ('ve', '366'),
#  ('366', 'ıncı'),
#  ('ıncı', 'maddelerine'),
#  ('maddelerine', 'uyduğu'),
#  ('uyduğu', 'iddiasıyla'),
#  ('iddiasıyla', 'eski'),
#  ('eski', 'Başbakan'),
#  ('Başbakan', 'Tansu'),
#  ('Tansu', 'Çiller'),
#  ('Çiller', 'hakkında'),
#  ('hakkında', 'Meclis'),
#  ('Meclis', 'soruşturması'),
#  ('soruşturması', 'açılmasına'),
#  ('açılmasına', 'ilişkin'),
#  ('ilişkin', 'önergesi'),
#  ('önergesi', '(9/3)'),
#  ('(9/3)', 'okundu;'),
#  ('okundu;', 'Meclis'),
#  ('Meclis', 'soruşturması'),
#  ('soruşturması', 'önergesi'),
#  ('önergesi', 'için'),
#  ('için', 'Anayasanın'),
#  ('Anayasanın', '100'),
#  ('100', 'üncü'),
#  ('üncü', 'maddesine'),
#  ('maddesine', 'göre'),
#  ('göre', 'en'),
#  ('en', 'geç'),
#  ('geç', 'bir'),
#  ('bir', 'ay'),
#  ('ay', 'içinde'),
#  ('içinde', 'olmak'),
#  ('olmak', 'üzere,'),
#  ('üzere,', 'Danışma'),
#  ('Danışma', 'Kurulunca'),
#  ('Kurulunca', 'tespit'),
#  ('tespit', 'edilecek'),
#  ('edilecek', 'görüşme'),
#  ('görüşme', 'gününün'),
#  ('gününün', 'Genel'),
#  ('Genel', 'Kurulun'),
#  ('Kurulun', 'onayına'),
#  ('onayına', 'sunulacağı'),
#  ('sunulacağı', 'açıklandı.'),
#  ('açıklandı.', 'Tokat'),
#  ('Tokat', 'Milletvekili'),
#  ('Milletvekili', 'Ahmet'),
#  ('Ahmet', 'Feyzi'),
#  ('Feyzi', 'İnceöz'),
#  ('İnceöz', 've'),
#  ('ve', '17'),
#  ('17', 'arkadaşının,'),
#  ('arkadaşının,', 'işsizlik'),
#  ('işsizlik', 'sorununun'),
#  ('sorununun', 'nedenlerinin'),
#  ('nedenlerinin', 'araştırılarak'),
#  ('araştırılarak', 'alınması'),
#  ('alınması', 'gereken'),
#  ('gereken', 'tedbirleri'),
#  ('tedbirleri', 'belirlemek;'),
#  ('belirlemek;', 'Tokat'),
#  ('Tokat', 'Milletvekili'),
#  ('Milletvekili', 'Ahmet'),
#  ('Ahmet', 'Feyzi'),
#  ('Feyzi', 'İnceöz'),
#  ('İnceöz', 've'),
#  ('ve', '16'),
#  ('16', 'arkadaşının,'),
#  ('arkadaşının,', 'korunmaya'),
#  ('korunmaya', 'muhtaç'),
#  ('muhtaç', 'çocukların'),
#  ('çocukların', 'sorunlarının'),
#  ('sorunlarının', 'araştırılarak'),
#  ('araştırılarak', 'gereken'),
#  ('gereken', 'tedbirlerin'),
#  ('tedbirlerin', 'belirlenmesi;'),
#  ('belirlenmesi;', 'Amacıyla'),
#  ('Amacıyla', 'birer'),
#  ('birer', 'Meclis'),
#  ('Meclis', 'araştırması'),
#  ('araştırması', 'açılmasına'),
#  ('açılmasına', 'ilişkin'),
#  ('ilişkin', 'önergeleri'),
#  ('önergeleri', '(10/61,'),
#  ('(10/61,', '10/62)'),
#  ('10/62)', 'okundu;'),
#  ('okundu;', 'önergelerin'),
#  ('önergelerin', 'gündemdeki'),
#  ('gündemdeki', 'yerlerini'),
#  ('yerlerini', 'alacağı'),
#  ('alacağı', 've'),
#  ('ve', 'öngörüşmelerinin,'),
#  ('öngörüşmelerinin,', 'sırasında'),
#  ('sırasında', 'yapılacağı'),
#  ('yapılacağı', 'açıklandı.'),
#  ('açıklandı.', 'RP'),
#  ('RP', 'Grup'),
#  ('Grup', 'Başkanvekili'),
#  ('Başkanvekili', 've'),
#  ('ve', 'İstanbul'),
#  ('İstanbul', 'Milletvekili'),
#  ('Milletvekili', 'İsmail'),
#  ('İsmail', 'Kahraman’ın,'),
#  ('Kahraman’ın,', 'TBMM'),
#  ('TBMM', 'Başkanlığınca'),
#  ('Başkanlığınca', 'Gruplarına'),
#  ('Gruplarına', 'verilen'),
#  ('verilen', 'cevabî'),
#  ('cevabî', 'yazıda'),
#  ('yazıda', 'partilerine'),
#  ('partilerine', 'sataşıldığı'),
#  ('sataşıldığı', 'iddiasıyla'),
#  ('iddiasıyla', 'söz'),
#  ('söz', 'isteminin'),
#  ('isteminin', 'Başkanlıkça'),
#  ('Başkanlıkça', 'uygun'),
#  ('uygun', 'görülmemesi'),
#  ('görülmemesi', 've'),
#  ('ve', 'kendisinin'),
#  ('kendisinin', 'de'),
#  ('de', 'söz'),
#  ...]

# %%
from collections import Counter
bigram_frequencies = Counter(bigrams_list)

# %%
for bigram in bigram_frequencies:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4b113097f725> in <module>
# ----> 1 bigram_frequencies/bigram_frequencies
#
# TypeError: unsupported operand type(s) for /: 'Counter' and 'Counter'

# %% [markdown]
# ### Donem<span style="color:red;"> 21<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 22<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 23<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 24<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 25<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 26<span>

# %% [markdown]
# ### Donem<span style="color:red;"> 27<span>
